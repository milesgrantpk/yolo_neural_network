# %% [markdown]
# # Convert Weights to TensorFlow 2.0 Weight Format

# %% [markdown]
# ### Importing required libraries

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from ipynb.fs.full.yolov3 import YOLOv3Net
from ipynb.fs.full.yolov3  import parse_cfg
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Load weights

# %%
def load_weights(model,cfgfile,weightfile):
    # Open the weights file
    fp = open(weightfile, "rb")

    # The first 5 values are header information
    np.fromfile(fp, dtype=np.int32, count=5)

    # Parse blocks from config file
    blocks = parse_cfg(cfgfile)

    for i, block in enumerate(blocks[1:]):
        if (block["type"] == "convolutional"):
            conv_layer = model.get_layer('conv_' + str(i))
            print("layer: ",i+1,conv_layer)
            filters = conv_layer.filters
            k_size = conv_layer.kernel_size[0]
            in_dim = conv_layer.input_shape[-1]
            if "batch_normalize" in block:
                norm_layer = model.get_layer('bnorm_' + str(i))
                print("layer: ",i+1,norm_layer)
                size = np.prod(norm_layer.get_weights()[0].shape)
                bn_weights = np.fromfile(fp, dtype=np.float32, count=4 * filters)
                # tf [gamma, beta, mean, variance]
                bn_weights = bn_weights.reshape((4, filters))[[1, 0, 2, 3]]
            else:
                conv_bias = np.fromfile(fp, dtype=np.float32, count=filters)
            # darknet shape (out_dim, in_dim, height, width)
            conv_shape = (filters, in_dim, k_size, k_size)
            conv_weights = np.fromfile(
                fp, dtype=np.float32, count=np.product(conv_shape))
            # tf shape (height, width, in_dim, out_dim)
            conv_weights = conv_weights.reshape(
                conv_shape).transpose([2, 3, 1, 0])
            if "batch_normalize" in block:
                norm_layer.set_weights(bn_weights)
                conv_layer.set_weights([conv_weights])
            else:
                conv_layer.set_weights([conv_weights, conv_bias])

    assert len(fp.read()) == 0, 'failed to read all data'
    fp.close()

# %% [markdown]
# ### Main method

# %%
def main():
    weightfile = "weights/yolov3.weights"
    cfgfile = "cfg/yolov3.cfg"
    model_size = (416, 416, 3)
    num_classes = 80
    model=YOLOv3Net(cfgfile,model_size,num_classes)
    load_weights(model,cfgfile,weightfile)
    try:
        model.save_weights('weights/yolov3_weights.tf')
        print('\nThe file \'yolov3_weights.tf\' has been saved successfully.')
    except IOError:
        print("Couldn't write the file \'yolov3_weights.tf\'.")

# %%
if __name__ == '__main__':
    main()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 416, 416, 3  0           []
#                                 )]
#
#  tf.math.truediv_9 (TFOpLambda)  (None, 416, 416, 3)  0          ['input_10[0][0]']
#
#  conv_0 (Conv2D)                (None, 416, 416, 32  864         ['tf.math.truediv_9[0][0]']
#                                 )
#
#  bnorm_0 (BatchNormalization)   (None, 416, 416, 32  128         ['conv_0[0][0]']
#                                 )
#
#  leaky_0 (LeakyReLU)            (None, 416, 416, 32  0           ['bnorm_0[0][0]']
#                                 )
#
#  zero_padding2d_9 (ZeroPadding2  (None, 417, 417, 32  0          ['leaky_0[0][0]']
#  D)                             )
#
#  conv_1 (Conv2D)                (None, 208, 208, 64  18432       ['zero_padding2d_9[0][0]']
#                                 )
#
#  bnorm_1 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_1[0][0]']
#                                 )
#
#  leaky_1 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_1[0][0]']
#                                 )
#
#  conv_2 (Conv2D)                (None, 208, 208, 32  2048        ['leaky_1[0][0]']
#                                 )
#
#  bnorm_2 (BatchNormalization)   (None, 208, 208, 32  128         ['conv_2[0][0]']
#                                 )
#
#  leaky_2 (LeakyReLU)            (None, 208, 208, 32  0           ['bnorm_2[0][0]']
#                                 )
#
#  conv_3 (Conv2D)                (None, 208, 208, 64  18432       ['leaky_2[0][0]']
#                                 )
#
#  bnorm_3 (BatchNormalization)   (None, 208, 208, 64  256         ['conv_3[0][0]']
#                                 )
#
#  leaky_3 (LeakyReLU)            (None, 208, 208, 64  0           ['bnorm_3[0][0]']
#                                 )
#
#  tf.__operators__.add (TFOpLamb  (None, 208, 208, 64  0          ['leaky_3[0][0]',
#  da)                            )                                 'leaky_1[0][0]']
#
#  zero_padding2d_10 (ZeroPadding  (None, 209, 209, 64  0          ['tf.__operators__.add[0][0]']
#  2D)                            )
#
#  conv_5 (Conv2D)                (None, 104, 104, 12  73728       ['zero_padding2d_10[0][0]']
#                                 8)
#
#  bnorm_5 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_5[0][0]']
#                                 8)
#
#  leaky_5 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_5[0][0]']
#                                 8)
#
#  conv_6 (Conv2D)                (None, 104, 104, 64  8192        ['leaky_5[0][0]']
#                                 )
#
#  bnorm_6 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_6[0][0]']
#                                 )
#
#  leaky_6 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_6[0][0]']
#                                 )
#
#  conv_7 (Conv2D)                (None, 104, 104, 12  73728       ['leaky_6[0][0]']
#                                 8)
#
#  bnorm_7 (BatchNormalization)   (None, 104, 104, 12  512         ['conv_7[0][0]']
#                                 8)
#
#  leaky_7 (LeakyReLU)            (None, 104, 104, 12  0           ['bnorm_7[0][0]']
#                                 8)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 104, 104, 12  0          ['leaky_7[0][0]',
#  mbda)                          8)                                'leaky_5[0][0]']
#
#  conv_9 (Conv2D)                (None, 104, 104, 64  8192        ['tf.__operators__.add_1[0][0]']
#                                 )
#
#  bnorm_9 (BatchNormalization)   (None, 104, 104, 64  256         ['conv_9[0][0]']
#                                 )
#
#  leaky_9 (LeakyReLU)            (None, 104, 104, 64  0           ['bnorm_9[0][0]']
#                                 )
#
#  conv_10 (Conv2D)               (None, 104, 104, 12  73728       ['leaky_9[0][0]']
#                                 8)
#
#  bnorm_10 (BatchNormalization)  (None, 104, 104, 12  512         ['conv_10[0][0]']
#                                 8)
#
#  leaky_10 (LeakyReLU)           (None, 104, 104, 12  0           ['bnorm_10[0][0]']
#                                 8)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 104, 104, 12  0          ['leaky_10[0][0]',
#  mbda)                          8)                                'tf.__operators__.add_1[0][0]']
#
#  zero_padding2d_11 (ZeroPadding  (None, 105, 105, 12  0          ['tf.__operators__.add_2[0][0]']
#  2D)                            8)
#
#  conv_12 (Conv2D)               (None, 52, 52, 256)  294912      ['zero_padding2d_11[0][0]']
#
#  bnorm_12 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_12[0][0]']
#
#  leaky_12 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_12[0][0]']
#
#  conv_13 (Conv2D)               (None, 52, 52, 128)  32768       ['leaky_12[0][0]']
#
#  bnorm_13 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_13[0][0]']
#
#  leaky_13 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_13[0][0]']
#
#  conv_14 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_13[0][0]']
#
#  bnorm_14 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_14[0][0]']
#
#  leaky_14 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_14[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_14[0][0]',
#  mbda)                                                            'leaky_12[0][0]']
#
#  conv_16 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_3[0][0]']
#
#  bnorm_16 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_16[0][0]']
#
#  leaky_16 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_16[0][0]']
#
#  conv_17 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_16[0][0]']
#
#  bnorm_17 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_17[0][0]']
#
#  leaky_17 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_17[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_17[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  conv_19 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_4[0][0]']
#
#  bnorm_19 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_19[0][0]']
#
#  leaky_19 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_19[0][0]']
#
#  conv_20 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_19[0][0]']
#
#  bnorm_20 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_20[0][0]']
#
#  leaky_20 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_20[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_20[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  conv_22 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_5[0][0]']
#
#  bnorm_22 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_22[0][0]']
#
#  leaky_22 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_22[0][0]']
#
#  conv_23 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_22[0][0]']
#
#  bnorm_23 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_23[0][0]']
#
#  leaky_23 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_23[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_23[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  conv_25 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_6[0][0]']
#
#  bnorm_25 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_25[0][0]']
#
#  leaky_25 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_25[0][0]']
#
#  conv_26 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_25[0][0]']
#
#  bnorm_26 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_26[0][0]']
#
#  leaky_26 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_26[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_26[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  conv_28 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_7[0][0]']
#
#  bnorm_28 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_28[0][0]']
#
#  leaky_28 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_28[0][0]']
#
#  conv_29 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_28[0][0]']
#
#  bnorm_29 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_29[0][0]']
#
#  leaky_29 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_29[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_29[0][0]',
#  mbda)                                                            'tf.__operators__.add_7[0][0]']
#
#  conv_31 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_8[0][0]']
#
#  bnorm_31 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_31[0][0]']
#
#  leaky_31 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_31[0][0]']
#
#  conv_32 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_31[0][0]']
#
#  bnorm_32 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_32[0][0]']
#
#  leaky_32 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_32[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 52, 52, 256)  0          ['leaky_32[0][0]',
#  mbda)                                                            'tf.__operators__.add_8[0][0]']
#
#  conv_34 (Conv2D)               (None, 52, 52, 128)  32768       ['tf.__operators__.add_9[0][0]']
#
#  bnorm_34 (BatchNormalization)  (None, 52, 52, 128)  512         ['conv_34[0][0]']
#
#  leaky_34 (LeakyReLU)           (None, 52, 52, 128)  0           ['bnorm_34[0][0]']
#
#  conv_35 (Conv2D)               (None, 52, 52, 256)  294912      ['leaky_34[0][0]']
#
#  bnorm_35 (BatchNormalization)  (None, 52, 52, 256)  1024        ['conv_35[0][0]']
#
#  leaky_35 (LeakyReLU)           (None, 52, 52, 256)  0           ['bnorm_35[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 52, 52, 256)  0          ['leaky_35[0][0]',
#  ambda)                                                           'tf.__operators__.add_9[0][0]']
#
#  zero_padding2d_12 (ZeroPadding  (None, 53, 53, 256)  0          ['tf.__operators__.add_10[0][0]']
#  2D)
#
#  conv_37 (Conv2D)               (None, 26, 26, 512)  1179648     ['zero_padding2d_12[0][0]']
#
#  bnorm_37 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_37[0][0]']
#
#  leaky_37 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_37[0][0]']
#
#  conv_38 (Conv2D)               (None, 26, 26, 256)  131072      ['leaky_37[0][0]']
#
#  bnorm_38 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_38[0][0]']
#
#  leaky_38 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_38[0][0]']
#
#  conv_39 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_38[0][0]']
#
#  bnorm_39 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_39[0][0]']
#
#  leaky_39 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_39[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 26, 26, 512)  0          ['leaky_39[0][0]',
#  ambda)                                                           'leaky_37[0][0]']
#
#  conv_41 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_11[0][0]']
#
#  bnorm_41 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_41[0][0]']
#
#  leaky_41 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_41[0][0]']
#
#  conv_42 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_41[0][0]']
#
#  bnorm_42 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_42[0][0]']
#
#  leaky_42 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_42[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 26, 26, 512)  0          ['leaky_42[0][0]',
#  ambda)                                                           'tf.__operators__.add_11[0][0]']
#
#  conv_44 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_12[0][0]']
#
#  bnorm_44 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_44[0][0]']
#
#  leaky_44 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_44[0][0]']
#
#  conv_45 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_44[0][0]']
#
#  bnorm_45 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_45[0][0]']
#
#  leaky_45 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_45[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 26, 26, 512)  0          ['leaky_45[0][0]',
#  ambda)                                                           'tf.__operators__.add_12[0][0]']
#
#  conv_47 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_13[0][0]']
#
#  bnorm_47 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_47[0][0]']
#
#  leaky_47 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_47[0][0]']
#
#  conv_48 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_47[0][0]']
#
#  bnorm_48 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_48[0][0]']
#
#  leaky_48 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_48[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 26, 26, 512)  0          ['leaky_48[0][0]',
#  ambda)                                                           'tf.__operators__.add_13[0][0]']
#
#  conv_50 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_14[0][0]']
#
#  bnorm_50 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_50[0][0]']
#
#  leaky_50 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_50[0][0]']
#
#  conv_51 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_50[0][0]']
#
#  bnorm_51 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_51[0][0]']
#
#  leaky_51 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_51[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 26, 26, 512)  0          ['leaky_51[0][0]',
#  ambda)                                                           'tf.__operators__.add_14[0][0]']
#
#  conv_53 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_15[0][0]']
#
#  bnorm_53 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_53[0][0]']
#
#  leaky_53 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_53[0][0]']
#
#  conv_54 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_53[0][0]']
#
#  bnorm_54 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_54[0][0]']
#
#  leaky_54 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_54[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 26, 26, 512)  0          ['leaky_54[0][0]',
#  ambda)                                                           'tf.__operators__.add_15[0][0]']
#
#  conv_56 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_16[0][0]']
#
#  bnorm_56 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_56[0][0]']
#
#  leaky_56 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_56[0][0]']
#
#  conv_57 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_56[0][0]']
#
#  bnorm_57 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_57[0][0]']
#
#  leaky_57 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_57[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 26, 26, 512)  0          ['leaky_57[0][0]',
#  ambda)                                                           'tf.__operators__.add_16[0][0]']
#
#  conv_59 (Conv2D)               (None, 26, 26, 256)  131072      ['tf.__operators__.add_17[0][0]']
#
#  bnorm_59 (BatchNormalization)  (None, 26, 26, 256)  1024        ['conv_59[0][0]']
#
#  leaky_59 (LeakyReLU)           (None, 26, 26, 256)  0           ['bnorm_59[0][0]']
#
#  conv_60 (Conv2D)               (None, 26, 26, 512)  1179648     ['leaky_59[0][0]']
#
#  bnorm_60 (BatchNormalization)  (None, 26, 26, 512)  2048        ['conv_60[0][0]']
#
#  leaky_60 (LeakyReLU)           (None, 26, 26, 512)  0           ['bnorm_60[0][0]']
#
#  tf.__operators__.add_18 (TFOpL  (None, 26, 26, 512)  0          ['leaky_60[0][0]',
#  ambda)                                                           'tf.__operators__.add_17[0][0]']
#
#  zero_padding2d_13 (ZeroPadding  (None, 27, 27, 512)  0          ['tf.__operators__.add_18[0][0]']
#  2D)
#
#  conv_62 (Conv2D)               (None, 13, 13, 1024  4718592     ['zero_padding2d_13[0][0]']
#                                 )
#
#  bnorm_62 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_62[0][0]']
#                                 )
#
#  leaky_62 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_62[0][0]']
#                                 )
#
#  conv_63 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_62[0][0]']
#
#  bnorm_63 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_63[0][0]']
#
#  leaky_63 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_63[0][0]']
#
#  conv_64 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_63[0][0]']
#                                 )
#
#  bnorm_64 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_64[0][0]']
#                                 )
#
#  leaky_64 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_64[0][0]']
#                                 )
#
#  tf.__operators__.add_19 (TFOpL  (None, 13, 13, 1024  0          ['leaky_64[0][0]',
#  ambda)                         )                                 'leaky_62[0][0]']
#
#  conv_66 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_19[0][0]']
#
#  bnorm_66 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_66[0][0]']
#
#  leaky_66 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_66[0][0]']
#
#  conv_67 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_66[0][0]']
#                                 )
#
#  bnorm_67 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_67[0][0]']
#                                 )
#
#  leaky_67 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_67[0][0]']
#                                 )
#
#  tf.__operators__.add_20 (TFOpL  (None, 13, 13, 1024  0          ['leaky_67[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_19[0][0]']
#
#  conv_69 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_20[0][0]']
#
#  bnorm_69 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_69[0][0]']
#
#  leaky_69 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_69[0][0]']
#
#  conv_70 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_69[0][0]']
#                                 )
#
#  bnorm_70 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_70[0][0]']
#                                 )
#
#  leaky_70 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_70[0][0]']
#                                 )
#
#  tf.__operators__.add_21 (TFOpL  (None, 13, 13, 1024  0          ['leaky_70[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_20[0][0]']
#
#  conv_72 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_21[0][0]']
#
#  bnorm_72 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_72[0][0]']
#
#  leaky_72 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_72[0][0]']
#
#  conv_73 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_72[0][0]']
#                                 )
#
#  bnorm_73 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_73[0][0]']
#                                 )
#
#  leaky_73 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_73[0][0]']
#                                 )
#
#  tf.__operators__.add_22 (TFOpL  (None, 13, 13, 1024  0          ['leaky_73[0][0]',
#  ambda)                         )                                 'tf.__operators__.add_21[0][0]']
#
#  conv_75 (Conv2D)               (None, 13, 13, 512)  524288      ['tf.__operators__.add_22[0][0]']
#
#  bnorm_75 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_75[0][0]']
#
#  leaky_75 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_75[0][0]']
#
#  conv_76 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_75[0][0]']
#                                 )
#
#  bnorm_76 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_76[0][0]']
#                                 )
#
#  leaky_76 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_76[0][0]']
#                                 )
#
#  conv_77 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_76[0][0]']
#
#  bnorm_77 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_77[0][0]']
#
#  leaky_77 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_77[0][0]']
#
#  conv_78 (Conv2D)               (None, 13, 13, 1024  4718592     ['leaky_77[0][0]']
#                                 )
#
#  bnorm_78 (BatchNormalization)  (None, 13, 13, 1024  4096        ['conv_78[0][0]']
#                                 )
#
#  leaky_78 (LeakyReLU)           (None, 13, 13, 1024  0           ['bnorm_78[0][0]']
#                                 )
#
#  conv_79 (Conv2D)               (None, 13, 13, 512)  524288      ['leaky_78[0][0]']
#
#  bnorm_79 (BatchNormalization)  (None, 13, 13, 512)  2048        ['conv_79[0][0]']
#
#  leaky_79 (LeakyReLU)           (None, 13, 13, 512)  0           ['bnorm_79[0][0]']
#
#  conv_84 (Conv2D)               (None, 13, 13, 256)  131072      ['leaky_79[0][0]']
#
# ...
#                                                                  0]']
#
#  tf.math.sigmoid_8 (TFOpLambda)  (None, 8112, 80)    0           ['tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  tf.concat_3 (TFOpLambda)       (None, 2535, 85)     0           ['tf.concat[0][0]',
#                                                                   'tf.concat_2[0][0]']
#
#  tf.concat_5 (TFOpLambda)       (None, 8112, 85)     0           ['tf.math.multiply_5[0][0]',
#                                                                   'tf.math.multiply_4[0][0]',
#                                                                   'tf.math.sigmoid_7[0][0]',
#                                                                   'tf.math.sigmoid_8[0][0]']
#
#  tf.concat_6 (TFOpLambda)       (None, 10647, 85)    0           ['tf.concat_3[0][0]',
#                                                                   'tf.concat_5[0][0]']
#
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# layer:  1 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F737790>
# layer:  1 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F8C5B80>
# layer:  2 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F366E12F10>
# layer:  2 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F74EEE0>
# layer:  3 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F731EE0>
# layer:  3 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F5B4700>
# layer:  4 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F6EB8E0>
# layer:  4 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F6759D0>
# layer:  6 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F6F6B20>
# layer:  6 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F6F6490>
# layer:  7 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F704D30>
# layer:  7 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F6AA2B0>
# layer:  8 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F704E50>
# layer:  8 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F6FBBB0>
# layer:  10 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F683520>
# layer:  10 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F714460>
# layer:  11 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F61D940>
# layer:  11 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F61C070>
# layer:  13 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F59CBB0>
# layer:  13 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F59C1C0>
# layer:  14 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F625BB0>
# layer:  14 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F5D2760>
# layer:  15 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F5D29A0>
# layer:  15 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36E34B550>
# layer:  17 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F562AC0>
# layer:  17 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F5A0190>
# layer:  18 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F689DF0>
# layer:  18 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F625C70>
# layer:  20 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F86E6D0>
# layer:  20 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F593520>
# layer:  21 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36794B100>
# layer:  21 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F593D30>
# layer:  23 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F98B490>
# layer:  23 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F992100>
# layer:  24 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F992A90>
# layer:  24 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FB8AD00>
# layer:  26 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FB34D90>
# layer:  26 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FB46430>
# layer:  27 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FB46850>
# layer:  27 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F9921F0>
# layer:  29 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F8DAA90>
# layer:  29 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F8D8220>
# layer:  30 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F8DFDF0>
# layer:  30 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F8DAC40>
# layer:  32 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F70BA00>
# layer:  32 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F8A7790>
# layer:  33 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F70BCA0>
# layer:  33 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F8D8B50>
# layer:  35 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F654C70>
# layer:  35 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F70BFD0>
# layer:  36 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FB5C8E0>
# layer:  36 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F70BC10>
# layer:  38 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F7048E0>
# layer:  38 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F689B80>
# layer:  39 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F6AAF40>
# layer:  39 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F641430>
# layer:  40 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F63B3A0>
# layer:  40 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F62D790>
# layer:  42 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F64A9A0>
# layer:  42 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F6511F0>
# layer:  43 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F5E3DC0>
# layer:  43 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F6337F0>
# layer:  45 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F6007F0>
# layer:  45 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F5F6A30>
# layer:  46 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F61B970>
# layer:  46 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F600D00>
# layer:  48 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FF70400>
# layer:  48 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FF77460>
# layer:  49 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FF859D0>
# layer:  49 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FF7F1F0>
# layer:  51 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FF8A250>
# layer:  51 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FF95250>
# layer:  52 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FF95FD0>
# layer:  52 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FF8E2B0>
# layer:  54 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F60D5B0>
# layer:  54 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FF95AC0>
# layer:  55 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F641A90>
# layer:  55 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FF955E0>
# layer:  57 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFA3340>
# layer:  57 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFA5430>
# layer:  58 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFA5BE0>
# layer:  58 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F6339D0>
# layer:  60 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFB1C10>
# layer:  60 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFAE5E0>
# layer:  61 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFA70A0>
# layer:  61 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFBD670>
# layer:  63 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFB59D0>
# layer:  63 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFB5C40>
# layer:  64 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFDCD30>
# layer:  64 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFDCBB0>
# layer:  65 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFDCEE0>
# layer:  65 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFD15E0>
# layer:  67 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFB5580>
# layer:  67 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFF8B50>
# layer:  68 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F370009EE0>
# layer:  68 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFBD220>
# layer:  70 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F370011F70>
# layer:  70 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F370011970>
# layer:  71 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFD1430>
# layer:  71 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFE9AC0>
# layer:  73 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFDCA00>
# layer:  73 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFB1E20>
# layer:  74 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFC4D30>
# layer:  74 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FF726D0>
# layer:  76 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F5F6A90>
# layer:  76 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFB1B50>
# layer:  77 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFCB640>
# layer:  77 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F37001E550>
# layer:  78 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F3700250A0>
# layer:  78 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFA9DF0>
# layer:  79 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F62D2B0>
# layer:  79 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F370025250>
# layer:  80 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F370040A00>
# layer:  80 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F37002D190>
# layer:  81 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F370046FA0>
# layer:  81 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F37003A070>
# layer:  82 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F370046C10>
# layer:  85 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F370078250>
# layer:  85 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F370046A00>
# layer:  88 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FF95310>
# layer:  88 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36FFDC160>
# layer:  89 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F37002D0A0>
# layer:  89 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F3700197F0>
# layer:  90 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFAEB20>
# layer:  90 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F37007FCA0>
# layer:  91 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36FFC4E80>
# layer:  91 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F370093070>
# layer:  92 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F370093160>
# layer:  92 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F370097430>
# layer:  93 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F3700B0130>
# layer:  93 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F3700A2190>
# layer:  94 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F3700B0EB0>
# layer:  97 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F37009BF10>
# layer:  97 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F3700B0B80>
# layer:  100 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F3700F3550>
# layer:  100 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F3700E0610>
# layer:  101 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F3700E0430>
# layer:  101 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F37008F8B0>
# layer:  102 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F37008F070>
# layer:  102 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F37008FAC0>
# layer:  103 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F3700F3F70>
# layer:  103 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F3700AA070>
# layer:  104 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F37006E970>
# layer:  104 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F36F5E3F40>
# layer:  105 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F36F5E3FA0>
# layer:  105 <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001F37009B1C0>
# layer:  106 <keras.layers.convolutional.conv2d.Conv2D object at 0x000001F37010F2B0>
#
# The file 'yolov3_weights.tf' has been saved successfully.
